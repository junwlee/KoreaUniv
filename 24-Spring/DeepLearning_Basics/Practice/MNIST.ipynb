# %%
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Input, Dense
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

model = Sequential()

model.add(Input(shape=(784,)))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='sigmoid'))

model.compile(
    optimizer='rmsprop', # Adam # AdaGrad
    loss='mse',
    metrics=['accuracy']
)

train_images = train_images.reshape((60000, 784))
train_images = train_images.astype('float32') / 255.0 # Normalize
test_images = test_images.reshape((10000, 784))
test_images = test_images.astype('float32') / 255.0

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# model.fit(train_images, train_labels, epochs=5, batch_size=128)

# %%
history = model.fit(train_images, train_labels, epochs=5, batch_size=128)
loss = history.history['loss']
acc = history.history['accuracy']
epochs = range(1, len(loss)+1)

plt.figure(1)
plt.plot(epochs, loss, 'b')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.title('Training Loss')

plt.figure(2)
plt.plot(epochs, acc, 'r', label='Accuracy')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.title('Training Accuracy')

plt.show()
# Out:
# Epoch 1/5
#  29/469 [>.............................] - ETA: 0s - loss: 0.0582 - accuracy: 0.7082
# 2024-05-14 22:32:33.817243: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0160 - accuracy: 0.9154
# Epoch 2/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0062 - accuracy: 0.9658
# Epoch 3/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0044 - accuracy: 0.9773
# Epoch 4/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0034 - accuracy: 0.9835
# Epoch 5/5
# 469/469 [==============================] - 1s 2ms/step - loss: 0.0027 - accuracy: 0.9864
